# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(50, 10, 100)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Bluberries", "Bananas", "Green Apples", "Cherries"]

plt.pie(y, labels = mylabels)
plt.show()
